# %% [markdown]
# # Create synthetic data for testing in a container

# %% [markdown]
# This notebook currently creates extremely basic arrays saved of as npy files so that containterized testing can be made with it's results. The point is to check containterized testing, not create realistic synthetic data

# %% [markdown]
# ## Imports

# %%
import numpy as np

# %% [markdown]
# ## Make some matrices

# %%
twodimarray1 = np.array([[10,20,30], [50,60,70], [10,11,11]])

# %%
twodimarray1.shape

# %%
threedimarray1 = np.dstack((twodimarray1, twodimarray1))

# %%
threedimarray1

# %%
threedimarray1.shape

# %%
twodimarray2 = np.array([[10,20,30], [52,60,70], [10,21,11]])
threedimarray2 = np.dstack((twodimarray2, twodimarray2))

# %%
twodimarray3 = np.array([[10,23,30], [53,60,70], [10,23,11]])
threedimarray3 = np.dstack((twodimarray3, twodimarray3))

# %%
np.save("ar1",threedimarray1)

# %%
np.save("ar2",threedimarray2)

# %%
np.save("ar3",threedimarray3)
